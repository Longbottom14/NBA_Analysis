# %%
#https://www.basketball-reference.com/friv/injuries.fcgi

# %%
import requests

# %%
standings_url = "https://www.basketball-reference.com/friv/injuries.fcgi"

# %%
data = requests.get(standings_url)

# %%
data.text
# Out:
# '\n<!DOCTYPE html>\n<html data-version="klecko-" data-root="/home/bbr/deploy/www" lang="en" class="no-js" >\n<head>\n    <meta charset="utf-8">\n    <meta http-equiv="x-ua-compatible" content="ie=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=2.0" />\n    <link rel="dns-prefetch" href="https://d2p3bygnnzw9w3.cloudfront.net/req/202205101" />\n    <!-- Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->\n<script type="text/javascript" async=true>\n    (function() {\n\tvar host = window.location.hostname;\n\tvar element = document.createElement(\'script\');\n\tvar firstScript = document.getElementsByTagName(\'script\')[0];\n\tvar url = \'https://quantcast.mgr.consensu.org\'\n\t    .concat(\'/choice/\', \'XwNYEpNeFfhfr\', \'/\', host, \'/choice.js\')\n\tvar uspTries = 0;\n\tvar uspTriesLimit = 3;\n\telement.async = true;\n\telement.type = \'text/javascript\';\n\telement.src = url;\n\t\n\tfirstScript.parentNode.insertBefore(element
# ...

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(data.text)

# %%
standings_table = soup.find(id ='table.injuries')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-fcf8542ba2f4> in <module>
# ----> 1 standings_table = soup.find(id ='table.injuries')
#
# NameError: name 'soup' is not defined

# %%
standings_table
# Out:
# []

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
matches = pd.read_html(data.text, match="54 Injuries")[0]

# %%
matches.Description[0]
# Out:
# 'Out (Shoulder) - Hauser is expected to miss a few weeks, according to John Karalis the Boston Sports Journal.'

# %%
matches
# Out:
#                      Player                    Team             Update  \
# 0                Sam Hauser          Boston Celtics   Sun, May 8, 2022
# 1           Robert Williams          Boston Celtics  Sat, May 21, 2022
# 2                Joe Harris           Brooklyn Nets   Thu, Mar 3, 2022
# 3               Ben Simmons           Brooklyn Nets  Sun, Apr 24, 2022
# 4                Lonzo Ball           Chicago Bulls   Wed, Apr 6, 2022
# 5             Collin Sexton     Cleveland Cavaliers  Fri, Nov 19, 2021
# 6                 Dean Wade     Cleveland Cavaliers  Mon, Mar 28, 2022
# 7              Tim Hardaway        Dallas Mavericks  Tue, Jan 25, 2022
# 8              Jamal Murray          Denver Nuggets  Thu, Jul 22, 2021
# 9            Michael Porter          Denver Nuggets  Sun, Feb 27, 2022
# 10           Hamidou Diallo         Detroit Pistons  Fri, Mar 25, 2022
# 11             Jerami Grant         Detroit Pistons  Mon, Mar 28, 2022
# ...
