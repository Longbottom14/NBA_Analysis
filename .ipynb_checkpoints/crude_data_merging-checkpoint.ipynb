# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)
from IPython.display import display

# %%
games = pd.read_csv("C:/Users/user/Solo Dolo/NBA_Analysis/Game\ATL\games.csv")#("C:/Users/user/Solo Dolo/NBA_Analysis/Game/DET/games.csv")

# %%
games
# Out:
#     Unnamed: 0   G               Date  Start (ET)  Unnamed: 3 Unnamed: 4  \
# 0            0   1  Thu, Oct 21, 2021       7:30p         NaN  Box Score
# 1            1   2  Sat, Oct 23, 2021       6:00p         NaN  Box Score
# 2            2   3  Mon, Oct 25, 2021       7:30p         NaN  Box Score
# 3            3   4  Wed, Oct 27, 2021       7:30p         NaN  Box Score
# 4            4   5  Thu, Oct 28, 2021       7:00p         NaN  Box Score
# ..         ...  ..                ...         ...         ...        ...
# 83          83   G               Date  Start (ET)         NaN        NaN
# 84          84  81   Fri, Apr 8, 2022       8:00p         NaN  Box Score
# 85          85  82  Sun, Apr 10, 2022       3:30p         NaN  Box Score
# 86          86  83  Wed, Apr 13, 2022       7:00p         NaN  Box Score
# 87          87  84  Fri, Apr 15, 2022       7:30p         NaN  Box Score
#
#    Unnamed: 5              Opponent Unnamed: 7 Unnamed: 8   Tm  Opp   W   L  \
# ...

# %%
games_column = ["idx","G" ,"Date" ,"Start (ET)","Nan1","BoxScore", "Venue","Opponent" ,"Result"," Nan2","Tm" ,"Opp" ,"W" ,"L" ,"Streak" ,"Notes"]
games.columns = games_column

# %%
games
# Out:
#     idx   G               Date  Start (ET)  Nan1   BoxScore Venue  \
# 0     0   1  Thu, Oct 21, 2021       7:30p   NaN  Box Score   NaN
# 1     1   2  Sat, Oct 23, 2021       6:00p   NaN  Box Score     @
# 2     2   3  Mon, Oct 25, 2021       7:30p   NaN  Box Score   NaN
# 3     3   4  Wed, Oct 27, 2021       7:30p   NaN  Box Score     @
# 4     4   5  Thu, Oct 28, 2021       7:00p   NaN  Box Score     @
# ..  ...  ..                ...         ...   ...        ...   ...
# 83   83   G               Date  Start (ET)   NaN        NaN   NaN
# 84   84  81   Fri, Apr 8, 2022       8:00p   NaN  Box Score     @
# 85   85  82  Sun, Apr 10, 2022       3:30p   NaN  Box Score     @
# 86   86  83  Wed, Apr 13, 2022       7:00p   NaN  Box Score   NaN
# 87   87  84  Fri, Apr 15, 2022       7:30p   NaN  Box Score     @
#
#                 Opponent Result  Nan2   Tm  Opp   W   L  Streak         Notes
# 0       Dallas Mavericks      W   NaN  113   87   1   0     W 1           NaN
# ...

# %%
indices_to_keep = games['G'].str.isdigit()#.isin([int]).any(1)

# %%
indices_to_keep
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#       ...
# 83    False
# 84     True
# 85     True
# 86     True
# 87     True
# Name: G, Length: 88, dtype: bool

# %%
idx2 = games['G']!='G'

# %%
idx2
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#       ...
# 83    False
# 84     True
# 85     True
# 86     True
# 87     True
# Name: G, Length: 88, dtype: bool

# %%
(indices_to_keep.values == idx2.values).sum()
# Out:
# 88

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88 entries, 0 to 87
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   idx         88 non-null     int64
#  1   G           88 non-null     object
#  2   Date        88 non-null     object
#  3   Start (ET)  88 non-null     object
#  4   Nan1        0 non-null      float64
#  5   BoxScore    84 non-null     object
#  6   Venue       42 non-null     object
#  7   Opponent    88 non-null     object
#  8   Result      84 non-null     object
#  9    Nan2       1 non-null      object
#  10  Tm          88 non-null     object
#  11  Opp         88 non-null     object
#  12  W           88 non-null     object
#  13  L           88 non-null     object
#  14  Streak      88 non-null     object
#  15  Notes       6 non-null      object
# dtypes: float64(1), int64(1), object(14)
# memory usage: 11.1+ KB

# %%
games[idx2].reset_index(drop=True)
# Out:
#     idx   G               Date Start (ET)  Nan1   BoxScore Venue  \
# 0     0   1  Thu, Oct 21, 2021      7:30p   NaN  Box Score   NaN
# 1     1   2  Sat, Oct 23, 2021      6:00p   NaN  Box Score     @
# 2     2   3  Mon, Oct 25, 2021      7:30p   NaN  Box Score   NaN
# 3     3   4  Wed, Oct 27, 2021      7:30p   NaN  Box Score     @
# 4     4   5  Thu, Oct 28, 2021      7:00p   NaN  Box Score     @
# ..  ...  ..                ...        ...   ...        ...   ...
# 79   82  80   Wed, Apr 6, 2022      8:00p   NaN  Box Score   NaN
# 80   84  81   Fri, Apr 8, 2022      8:00p   NaN  Box Score     @
# 81   85  82  Sun, Apr 10, 2022      3:30p   NaN  Box Score     @
# 82   86  83  Wed, Apr 13, 2022      7:00p   NaN  Box Score   NaN
# 83   87  84  Fri, Apr 15, 2022      7:30p   NaN  Box Score     @
#
#                 Opponent Result  Nan2   Tm  Opp   W   L Streak         Notes
# 0       Dallas Mavericks      W   NaN  113   87   1   0    W 1           NaN
# ...

# %%
games.Opponent.value_counts()
# Out:
# Cleveland Cavaliers       5
# Charlotte Hornets         5
# Toronto Raptors           4
# Orlando Magic             4
# New York Knicks           4
# Opponent                  4
# Chicago Bulls             4
# Boston Celtics            4
# Indiana Pacers            4
# Washington Wizards        4
# Miami Heat                4
# Milwaukee Bucks           3
# Brooklyn Nets             3
# Philadelphia 76ers        3
# Detroit Pistons           3
# Sacramento Kings          2
# Minnesota Timberwolves    2
# Los Angeles Lakers        2
# Los Angeles Clippers      2
# Houston Rockets           2
# Portland Trail Blazers    2
# Dallas Mavericks          2
# Memphis Grizzlies         2
# San Antonio Spurs         2
# Denver Nuggets            2
# Golden State Warriors     2
# Phoenix Suns              2
# Utah Jazz                 2
# New Orleans Pelicans      2
# Oklahoma City Thunder     2
# Name: Opponent, dtype: int64

# %%
gamelog = pd.read_csv("C:/Users/user/Solo Dolo/NBA_Analysis/Game\ATL\gamelog.csv")#("C:/Users/user/Solo Dolo/NBA_Analysis/Game/DET/games.csv")

# %%
gamelog
# Out:
#     Unnamed: 0 Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
# 0          NaN                 Rk                  G               Date
# 1          0.0                  1                  1         2021-10-21
# 2          1.0                  2                  2         2021-10-23
# 3          2.0                  3                  3         2021-10-25
# 4          3.0                  4                  4         2021-10-27
# ..         ...                ...                ...                ...
# 86        85.0                 80                 80         2022-04-06
# 87        86.0                NaN                NaN                NaN
# 88        87.0                 Rk                  G               Date
# 89        88.0                 81                 81         2022-04-08
# 90        89.0                 82                 82         2022-04-10
#
#     Unnamed: 3_level_0 Unnamed: 4_level_0 Unnamed: 5_level_0  \
# ...

# %%
Rk G 	Date 	  	Opp 	W/L 	Tm 	Opp

# %%
gamelog.iloc[0]
# Out:
# Unnamed: 0                             NaN
# Unnamed: 0_level_0                      Rk
# Unnamed: 1_level_0                       G
# Unnamed: 2_level_0                    Date
# Unnamed: 3_level_0      Unnamed: 3_level_1
# Unnamed: 4_level_0                     Opp
# Unnamed: 5_level_0                     W/L
# Unnamed: 6_level_0                      Tm
# Unnamed: 7_level_0                     Opp
# Team                                    FG
# Team.1                                 FGA
# Team.2                                 FG%
# Team.3                                  3P
# Team.4                                 3PA
# Team.5                                 3P%
# Team.6                                  FT
# Team.7                                 FTA
# Team.8                                 FT%
# Team.9                                 ORB
# Team.10                                TRB
# Team.11                                AST
# Team.12                                STL
# ...

# %%
gamelog.iloc[0].values
# Out:
# array([nan, 'Rk', 'G', 'Date', 'Unnamed: 3_level_1', 'Opp', 'W/L', 'Tm',
#        'Opp', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%',
#        'ORB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF',
#        'Unnamed: 24_level_1', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%',
#        'FT', 'FTA', 'FT%', 'ORB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF'],
#       dtype=object)

# %%
col1 = ["idx", 'Rk', 'G', 'Date', 'Venue', 'Opponent', 'W/L', 'Tm',
       'Opp']
common_col = ['FG', 'FGA', 'FG%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%',
       'ORB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF',]
team_col = ["Tm_"+col for col in common_col]
opp_col = ["Opp_"+col for col in common_col]
gamelog_columns = col1+team_col+['Nan1']+opp_col

# %%
gamelog_columns
# Out:
# ['idx',
#  'Rk',
#  'G',
#  'Date',
#  'Venue',
#  'Opponent',
#  'W/L',
#  'Tm',
#  'Opp',
#  'Tm_FG',
#  'Tm_FGA',
#  'Tm_FG%',
#  'Tm_3P',
#  'Tm_3PA',
#  'Tm_3P%',
#  'Tm_FT',
#  'Tm_FTA',
#  'Tm_FT%',
#  'Tm_ORB',
#  'Tm_TRB',
#  'Tm_AST',
#  'Tm_STL',
#  'Tm_BLK',
#  'Tm_TOV',
#  'Tm_PF',
#  'Nan1',
#  'Opp_FG',
#  'Opp_FGA',
#  'Opp_FG%',
#  'Opp_3P',
#  'Opp_3PA',
#  'Opp_3P%',
#  'Opp_FT',
#  'Opp_FTA',
#  'Opp_FT%',
#  'Opp_ORB',
#  'Opp_TRB',
#  'Opp_AST',
#  'Opp_STL',
#  'Opp_BLK',
#  'Opp_TOV',
#  'Opp_PF']

# %%
gamelog.columns = gamelog_columns

# %%
gamelog
# Out:
#      idx   Rk    G        Date               Venue Opponent  W/L   Tm  Opp  \
# 0    NaN   Rk    G        Date  Unnamed: 3_level_1      Opp  W/L   Tm  Opp
# 1    0.0    1    1  2021-10-21                 NaN      DAL    W  113   87
# 2    1.0    2    2  2021-10-23                   @      CLE    L   95  101
# 3    2.0    3    3  2021-10-25                 NaN      DET    W  122  104
# 4    3.0    4    4  2021-10-27                   @      NOP    W  102   99
# ..   ...  ...  ...         ...                 ...      ...  ...  ...  ...
# 86  85.0   80   80  2022-04-06                 NaN      WAS    W  118  103
# 87  86.0  NaN  NaN         NaN                 NaN      NaN  NaN  NaN  NaN
# 88  87.0   Rk    G        Date                 NaN      Opp  W/L   Tm  Opp
# 89  88.0   81   81  2022-04-08                   @      MIA    L  109  113
# 90  89.0   82   82  2022-04-10                   @      HOU    W  130  114
#
# ...

# %%
#'DEN' in 
gamelog.Opponent.value_counts().index
# Out:
# Index(['Opp', 'ORL', 'MIA', 'CHI', 'IND', 'NYK', 'BOS', 'CHO', 'WAS', 'CLE',
#        'TOR', 'BRK', 'PHI', 'MIL', 'DET', 'DEN', 'HOU', 'GSW', 'LAC', 'LAL',
#        'SAC', 'POR', 'NOP', 'MIN', 'PHO', 'MEM', 'SAS', 'OKC', 'DAL', 'UTA'],
#       dtype='object')

# %%
indices_to_keep = (gamelog['G']!= 'G') & (gamelog['G'].str.isdigit())#.str.isdigit()#.isin([int]).any(1)

# %%
indices_to_keep#.drop("NaN")
# Out:
# 0     False
# 1      True
# 2      True
# 3      True
# 4      True
#       ...
# 86     True
# 87    False
# 88    False
# 89     True
# 90     True
# Name: G, Length: 91, dtype: bool

# %%
gamelog[indices_to_keep].reset_index(drop=True)
# Out:
#      idx  Rk   G        Date Venue Opponent W/L   Tm  Opp Tm_FG Tm_FGA Tm_FG%  \
# 0    0.0   1   1  2021-10-21   NaN      DAL   W  113   87    45     94   .479
# 1    1.0   2   2  2021-10-23     @      CLE   L   95  101    38     99   .384
# 2    2.0   3   3  2021-10-25   NaN      DET   W  122  104    46     90   .511
# 3    3.0   4   4  2021-10-27     @      NOP   W  102   99    40     96   .417
# 4    4.0   5   5  2021-10-28     @      WAS   L  111  122    48     88   .545
# ..   ...  ..  ..         ...   ...      ...  ..  ...  ...   ...    ...    ...
# 77  83.0  78  78  2022-04-02   NaN      BRK   W  122  115    36     86   .419
# 78  84.0  79  79  2022-04-05     @      TOR   L  108  118    43     94   .457
# 79  85.0  80  80  2022-04-06   NaN      WAS   W  118  103    43     92   .467
# 80  88.0  81  81  2022-04-08     @      MIA   L  109  113    42     88   .477
# 81  89.0  82  82  2022-04-10     @      HOU   W  130  114    45     87   .517
#
# ...

# %%
game_advance_stats = pd.read_csv("C:/Users/user/Solo Dolo/NBA_Analysis/Game\ATL\game_advance_stats.csv")

# %%
game_advance_stats
# Out:
#     Unnamed: 0 Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
# 0          NaN                 Rk                  G               Date
# 1          0.0                  1                  1         2021-10-21
# 2          1.0                  2                  2         2021-10-23
# 3          2.0                  3                  3         2021-10-25
# 4          3.0                  4                  4         2021-10-27
# ..         ...                ...                ...                ...
# 86        85.0                 80                 80         2022-04-06
# 87        86.0                NaN                NaN                NaN
# 88        87.0                 Rk                  G               Date
# 89        88.0                 81                 81         2022-04-08
# 90        89.0                 82                 82         2022-04-10
#
#     Unnamed: 3_level_0 Unnamed: 4_level_0 Unnamed: 5_level_0  \
# ...

# %%
game_advance_stats.iloc[0]
# Out:
# Unnamed: 0                                  NaN
# Unnamed: 0_level_0                           Rk
# Unnamed: 1_level_0                            G
# Unnamed: 2_level_0                         Date
# Unnamed: 3_level_0           Unnamed: 3_level_1
# Unnamed: 4_level_0                          Opp
# Unnamed: 5_level_0                          W/L
# Unnamed: 6_level_0                           Tm
# Unnamed: 7_level_0                          Opp
# Advanced                                   ORtg
# Advanced.1                                 DRtg
# Advanced.2                                 Pace
# Advanced.3                                  FTr
# Advanced.4                                 3PAr
# Advanced.5                                  TS%
# Advanced.6                                 TRB%
# Advanced.7                                 AST%
# Advanced.8                                 STL%
# Advanced.9                                 BLK%
# Unnamed: 18_level_0         Unnamed: 18_level_1
# ...

# %%
game_advance_stats.iloc[0].values
# Out:
# array([nan, 'Rk', 'G', 'Date', 'Unnamed: 3_level_1', 'Opp', 'W/L', 'Tm',
#        'Opp', 'ORtg', 'DRtg', 'Pace', 'FTr', '3PAr', 'TS%', 'TRB%',
#        'AST%', 'STL%', 'BLK%', 'Unnamed: 18_level_1', 'eFG%', 'TOV%',
#        'ORB%', 'FT/FGA', 'Unnamed: 23_level_1', 'eFG%', 'TOV%', 'DRB%',
#        'FT/FGA'], dtype=object)

# %%
col1=['idx', 'Rk', 'G', 'Date', 'Venue', 'Opponent', 'W/L', 'Tm','Opp']

advanced = ["Adv_Tm_"+col for col in 
            ['ORtg', 'DRtg', 'Pace', 'FTr', '3PAr', 'TS%', 'TRB%','AST%', 'STL%', 'BLK%']]

Nan1 = ["Nan1"]

offensive4F = ["Adv_Tm_O_4F_"+col for col in 
    ['eFG%', 'TOV%','ORB%', 'FT/FGA']]

Nan2 = ["Nan2"]

deffensive4F = ["Adv_Tm_D_4F_"+col for col in 
    ['eFG%', 'TOV%','DRB%', 'FT/FGA']]

# %%
advanced_columns = col1+advanced+['Nan1']+offensive4F+Nan2+deffensive4F

# %%
advanced_columns
# Out:
# ['idx',
#  'Rk',
#  'G',
#  'Date',
#  'Venue',
#  'Opponent',
#  'W/L',
#  'Tm',
#  'Opp',
#  'Adv_Tm_ORtg',
#  'Adv_Tm_DRtg',
#  'Adv_Tm_Pace',
#  'Adv_Tm_FTr',
#  'Adv_Tm_3PAr',
#  'Adv_Tm_TS%',
#  'Adv_Tm_TRB%',
#  'Adv_Tm_AST%',
#  'Adv_Tm_STL%',
#  'Adv_Tm_BLK%',
#  'Nan1',
#  'Adv_Tm_O_4F_eFG%',
#  'Adv_Tm_O_4F_TOV%',
#  'Adv_Tm_O_4F_ORB%',
#  'Adv_Tm_O_4F_FT/FGA',
#  'Nan2',
#  'Adv_Tm_D_4F_eFG%',
#  'Adv_Tm_D_4F_TOV%',
#  'Adv_Tm_D_4F_DRB%',
#  'Adv_Tm_D_4F_FT/FGA']

# %%
game_advance_stats.columns = advanced_columns

# %%
game_advance_stats
# Out:
#      idx   Rk    G        Date               Venue Opponent  W/L   Tm  Opp  \
# 0    NaN   Rk    G        Date  Unnamed: 3_level_1      Opp  W/L   Tm  Opp
# 1    0.0    1    1  2021-10-21                 NaN      DAL    W  113   87
# 2    1.0    2    2  2021-10-23                   @      CLE    L   95  101
# 3    2.0    3    3  2021-10-25                 NaN      DET    W  122  104
# 4    3.0    4    4  2021-10-27                   @      NOP    W  102   99
# ..   ...  ...  ...         ...                 ...      ...  ...  ...  ...
# 86  85.0   80   80  2022-04-06                 NaN      WAS    W  118  103
# 87  86.0  NaN  NaN         NaN                 NaN      NaN  NaN  NaN  NaN
# 88  87.0   Rk    G        Date                 NaN      Opp  W/L   Tm  Opp
# 89  88.0   81   81  2022-04-08                   @      MIA    L  109  113
# 90  89.0   82   82  2022-04-10                   @      HOU    W  130  114
#
# ...

# %%
indices_to_keep = (game_advance_stats['G']!= 'G') & (game_advance_stats['G'].str.isdigit())

# %%
game_advance_stats[indices_to_keep].reset_index(drop=True)
# Out:
#      idx  Rk   G        Date Venue Opponent W/L   Tm  Opp Adv_Tm_ORtg  \
# 0    0.0   1   1  2021-10-21   NaN      DAL   W  113   87       109.9
# 1    1.0   2   2  2021-10-23     @      CLE   L   95  101        99.3
# 2    2.0   3   3  2021-10-25   NaN      DET   W  122  104       123.1
# 3    3.0   4   4  2021-10-27     @      NOP   W  102   99       110.2
# 4    4.0   5   5  2021-10-28     @      WAS   L  111  122       111.9
# ..   ...  ..  ..         ...   ...      ...  ..  ...  ...         ...
# 77  83.0  78  78  2022-04-02   NaN      BRK   W  122  115       116.4
# 78  84.0  79  79  2022-04-05     @      TOR   L  108  118       112.3
# 79  85.0  80  80  2022-04-06   NaN      WAS   W  118  103       121.4
# 80  88.0  81  81  2022-04-08     @      MIA   L  109  113       114.4
# 81  89.0  82  82  2022-04-10     @      HOU   W  130  114       137.4
#
#    Adv_Tm_DRtg Adv_Tm_Pace Adv_Tm_FTr Adv_Tm_3PAr Adv_Tm_TS% Adv_Tm_TRB%  \
# ...

# %%
H2H = pd.read_csv("C:/Users/user/Solo Dolo/NBA_Analysis/Game\ATL\H2H.csv")

# %%
H2H
# Out:
#     Unnamed: 0  Rk               Franchise    G    W    L   W/L%     PS  \
# 0            0   1        Anderson Packers    9    2    7  0.222    739
# 1            1   2       Baltimore Bullets   28   16   12  0.571   2173
# 2            2   3          Boston Celtics  386  147  239  0.381  39586
# 3            3   4           Brooklyn Nets  188  103   85  0.548  19607
# 4            4   5       Charlotte Hornets  126   67   59  0.532  12888
# 5            5   6           Chicago Bulls  252  117  135  0.464  25556
# 6            6   7           Chicago Stags    2    1    1  0.500    141
# 7            7   8     Cleveland Cavaliers  236  127  109  0.538  24192
# 8            8   9        Dallas Mavericks   82   45   37  0.549   8398
# 9            9  10          Denver Nuggets    7    7    0  1.000    685
# 10          10  11          Denver Nuggets   95   51   44  0.537  10111
# 11          11  12         Detroit Pistons  438  213  225  0.486  44340
# ...

# %%
H2

# %%
games.Opponent.nunique()
# Out:
# 30

# %%
h1=H2H[H2H.Franchise.isin(games.Opponent.unique())].reset_index(drop=True)

# %%
h1
# Out:
#     Unnamed: 0  Rk               Franchise    G    W    L   W/L%     PS  \
# 0            2   3          Boston Celtics  386  147  239  0.381  39586
# 1            3   4           Brooklyn Nets  188  103   85  0.548  19607
# 2            4   5       Charlotte Hornets  126   67   59  0.532  12888
# 3            5   6           Chicago Bulls  252  117  135  0.464  25556
# 4            7   8     Cleveland Cavaliers  236  127  109  0.538  24192
# 5            8   9        Dallas Mavericks   82   45   37  0.549   8398
# 6            9  10          Denver Nuggets    7    7    0  1.000    685
# 7           10  11          Denver Nuggets   95   51   44  0.537  10111
# 8           11  12         Detroit Pistons  438  213  225  0.486  44340
# 9           12  13   Golden State Warriors  297  147  150  0.495  31242
# 10          13  14         Houston Rockets  160   79   81  0.494  17079
# 11          14  15          Indiana Pacers  201  107   94  0.532  20710
# ...

# %%
h1.Franchise.value_counts()[h1.Franchise.value_counts()>1].index[0]
# Out:
# 'Denver Nuggets'

# %%
h1[h1.Franchise=='Denver Nuggets']
# Out:
#    Unnamed: 0  Rk       Franchise   G   W   L   W/L%     PS     PA   PS/G  \
# 6           9  10  Denver Nuggets   7   7   0  1.000    685    566   97.9
# 7          10  11  Denver Nuggets  95  51  44  0.537  10111  10116  106.4
#
#     PA/G
# 6   80.9
# 7  106.5

# %%
h1[h1.Franchise=='Denver Nuggets']['G'].max()
# Out:
# 95

# %%
h1[h1.Franchise=='Denver Nuggets'].index
# Out:
# Int64Index([6, 7], dtype='int64')

# %%
h1.iloc[6]
# Out:
# Unnamed: 0                 9
# Rk                        10
# Franchise     Denver Nuggets
# G                          7
# W                          7
# L                          0
# W/L%                     1.0
# PS                       685
# PA                       566
# PS/G                    97.9
# PA/G                    80.9
# Name: 6, dtype: object

# %%
h1[(h1.Franchise=='Denver Nuggets')&(h1.G!=95)]
# Out:
#    Unnamed: 0  Rk       Franchise  G  W  L  W/L%   PS   PA  PS/G  PA/G
# 6           9  10  Denver Nuggets  7  7  0   1.0  685  566  97.9  80.9

# %%
h2 = h1.drop(h1[(h1.Franchise=='Denver Nuggets')&(h1.G!=95)].index)

# %%
h2
# Out:
#     Unnamed: 0  Rk               Franchise    G    W    L   W/L%     PS  \
# 0            2   3          Boston Celtics  386  147  239  0.381  39586
# 1            3   4           Brooklyn Nets  188  103   85  0.548  19607
# 2            4   5       Charlotte Hornets  126   67   59  0.532  12888
# 3            5   6           Chicago Bulls  252  117  135  0.464  25556
# 4            7   8     Cleveland Cavaliers  236  127  109  0.538  24192
# 5            8   9        Dallas Mavericks   82   45   37  0.549   8398
# 7           10  11          Denver Nuggets   95   51   44  0.537  10111
# 8           11  12         Detroit Pistons  438  213  225  0.486  44340
# 9           12  13   Golden State Warriors  297  147  150  0.495  31242
# 10          13  14         Houston Rockets  160   79   81  0.494  17079
# 11          14  15          Indiana Pacers  201  107   94  0.532  20710
# 12          16  17    Los Angeles Clippers  128   80   48  0.625  13535
# ...

# %%
def clean_H2H(H2H_df):#,games_df):
    H2H_df= H2H_df.copy()
    print("before")
    display(H2H_df[H2H_df.Franchise=='Denver Nuggets'])
    #games_df = games_df.copy()
    #h1 = H2H_df[H2H_df.Franchise.isin(games_df.Opponent.unique())].reset_index(drop=True)
    #repeated = h1.Franchise.value_counts()[h1.Franchise.value_counts()>1].index[0]
    val_count = H2H_df.Franchise.value_counts()
    if len(val_count[H2H_df.Franchise.value_counts()>1])>0:
        max_game = H2H_df[H2H_df.Franchise=='Denver Nuggets']['G'].max()
        H2H_df = H2H_df.drop(H2H_df[(H2H_df.Franchise=='Denver Nuggets')&(H2H_df.G!=max_game)].index)
    print()
    print("after")
    display(H2H_df[H2H_df.Franchise=='Denver Nuggets'])
    return H2H_df

# %%
H2H
# Out:
#     Unnamed: 0  Rk               Franchise    G    W    L   W/L%     PS  \
# 0            0   1        Anderson Packers    9    2    7  0.222    739
# 1            1   2       Baltimore Bullets   28   16   12  0.571   2173
# 2            2   3          Boston Celtics  386  147  239  0.381  39586
# 3            3   4           Brooklyn Nets  188  103   85  0.548  19607
# 4            4   5       Charlotte Hornets  126   67   59  0.532  12888
# 5            5   6           Chicago Bulls  252  117  135  0.464  25556
# 6            6   7           Chicago Stags    2    1    1  0.500    141
# 7            7   8     Cleveland Cavaliers  236  127  109  0.538  24192
# 8            8   9        Dallas Mavericks   82   45   37  0.549   8398
# 9            9  10          Denver Nuggets    7    7    0  1.000    685
# 10          10  11          Denver Nuggets   95   51   44  0.537  10111
# 11          11  12         Detroit Pistons  438  213  225  0.486  44340
# ...

# %%
clean_H2H(H2H_df=H2H)
# Out:
# before
#    Unnamed: 0  Rk       Franchise   G   W   L   W/L%     PS     PA   PS/G  \
# 7           7   8  Denver Nuggets  96  41  55  0.427  10124  10305  105.5
#
#     PA/G
# 7  107.3
# after
#    Unnamed: 0  Rk       Franchise   G   W   L   W/L%     PS     PA   PS/G  \
# 7           7   8  Denver Nuggets  96  41  55  0.427  10124  10305  105.5
#
#     PA/G
# 7  107.3
#     Unnamed: 0  Rk               Franchise    G    W    L   W/L%     PS  \
# 0            0   1           Atlanta Hawks  312  150  162  0.481  32728
# 1            1   2          Boston Celtics  315  119  196  0.378  33174
# 2            2   3           Brooklyn Nets  199  107   92  0.538  20493
# 3            3   4       Charlotte Hornets  124   56   68  0.452  12664
# 4            4   5           Chicago Bulls  236  107  129  0.453  23922
# 5            5   6     Cleveland Cavaliers  228  118  110  0.518  23194
# 6            6   7        Dallas Mavericks   81   35   46  0.432   8256
# ...

# %%
teams =['ATL',
 'BOS',
 'NJN',
 'CHA',
 'CHI',
 'CLE',
 'DAL',
 'DEN',
 'DET',
 'GSW',
 'HOU',
 'IND',
 'LAC',
 'LAL',
 'MEM',
 'MIA',
 'MIL',
 'MIN',
 'NOH',
 'NYK',
 'OKC',
 'ORL',
 'PHI',
 'PHO',
 'POR',
 'SAC',
 'SAS',
 'TOR',
 'UTA',
 'WAS']
fault = ['NJN', 'CHA', 'NOH']

# %%
for element in fault:
    teams.remove(element)
teams
# Out:
# ['ATL',
#  'BOS',
#  'CHI',
#  'CLE',
#  'DAL',
#  'DEN',
#  'DET',
#  'GSW',
#  'HOU',
#  'IND',
#  'LAC',
#  'LAL',
#  'MEM',
#  'MIA',
#  'MIL',
#  'MIN',
#  'NYK',
#  'OKC',
#  'ORL',
#  'PHI',
#  'PHO',
#  'POR',
#  'SAC',
#  'SAS',
#  'TOR',
#  'UTA',
#  'WAS']

# %%
#"C:/Users/user/Solo Dolo/NBA_Analysis/Game\ATL\H2H.csv"

# %%
for team in teams:
    H2H = pd.read_csv("C://Users//user//Solo Dolo//NBA_Analysis//Game//"+team+"//H2H.csv")
    #display(H2H.head(3))
    h1=H2H
    #display(h1.head(10))
    print(team)
    val_count = h1.Franchise.value_counts()
    display(val_count[h1.Franchise.value_counts()>1])#[h1.Franchise.value_counts()>1]#.index[0]
    if len(val_count[h1.Franchise.value_counts()>1])>0:
        display(*(val_count[h1.Franchise.value_counts()>1].index))
        
    print()
    print()
# Out:
# ATL
# Denver Nuggets    2
# Name: Franchise, dtype: int64
# 'Denver Nuggets'
# BOS
# Denver Nuggets    2
# Name: Franchise, dtype: int64
# 'Denver Nuggets'
# CHI
# Series([], Name: Franchise, dtype: int64)
# CLE
# Series([], Name: Franchise, dtype: int64)
# DAL
# Series([], Name: Franchise, dtype: int64)
# DEN
# Series([], Name: Franchise, dtype: int64)
# DET
# Denver Nuggets    2
# Name: Franchise, dtype: int64
# 'Denver Nuggets'
# GSW
# Denver Nuggets    2
# Name: Franchise, dtype: int64
# 'Denver Nuggets'
# HOU
# Series([], Name: Franchise, dtype: int64)
# IND
# Series([], Name: Franchise, dtype: int64)
# LAC
# Series([], Name: Franchise, dtype: int64)
# LAL
# Denver Nuggets    2
# Name: Franchise, dtype: int64
# 'Denver Nuggets'
# MEM
# Series([], Name: Franchise, dtype: int64)
# MIA
# Series([], Name: Franchise, dtype: int64)
# MIL
# Series([], Name: Franchise, dtype: int64)
# MIN
# Series([], Name: Franchise, dtype: int64)
# NYK
# Denver Nuggets    2
# ...

# %%
for team in teams:
    print("team : ",team)
    H2H = pd.read_csv("C://Users//user//Solo Dolo//NBA_Analysis//Game//"+team+"//H2H.csv")
    clean_H2H(H2H_df=H2H)
    print()
# Out:
# team :  ATL
# before
#     Unnamed: 0  Rk       Franchise   G   W   L   W/L%     PS     PA   PS/G  \
# 9            9  10  Denver Nuggets   7   7   0  1.000    685    566   97.9
# 10          10  11  Denver Nuggets  95  51  44  0.537  10111  10116  106.4
#
#      PA/G
# 9    80.9
# 10  106.5
# after
#     Unnamed: 0  Rk       Franchise   G   W   L   W/L%     PS     PA   PS/G  \
# 10          10  11  Denver Nuggets  95  51  44  0.537  10111  10116  106.4
#
#      PA/G
# 10  106.5
# team :  BOS
# before
#     Unnamed: 0  Rk       Franchise   G   W   L   W/L%     PS     PA   PS/G  \
# 10          10  11  Denver Nuggets   2   1   1  0.500    175    168   87.5
# 11          11  12  Denver Nuggets  96  59  37  0.615  10500  10231  109.4
#
#      PA/G
# 10   84.0
# 11  106.6
# after
#     Unnamed: 0  Rk       Franchise   G   W   L   W/L%     PS     PA   PS/G  \
# 11          11  12  Denver Nuggets  96  59  37  0.615  10500  10231  109.4
#
#      PA/G
# 11  106.6
# team :  CHI
# before
# ...

# %%
prev_season = pd.read_csv("C:/Users/user/Solo Dolo/NBA_Analysis/Game\ATL\prev_season.csv")

# %%
prev_season
# Out:
#     Unnamed: 0   Season   Lg                    Team   W   L   W/L%    Finish  \
# 0            0  2021-22  NBA          Atlanta Hawks*  43  39  0.524  2nd of 5
# 1            1  2020-21  NBA          Atlanta Hawks*  41  31  0.569  1st of 5
# 2            2  2019-20  NBA           Atlanta Hawks  20  47  0.299  5th of 5
# 3            3  2018-19  NBA           Atlanta Hawks  29  53  0.354  5th of 5
# 4            4  2017-18  NBA           Atlanta Hawks  24  58  0.293  5th of 5
# ..         ...      ...  ...                     ...  ..  ..    ...       ...
# 68          68  1953-54  NBA         Milwaukee Hawks  21  51  0.292  4th of 4
# 69          69  1952-53  NBA         Milwaukee Hawks  27  44  0.380  5th of 5
# 70          70  1951-52  NBA         Milwaukee Hawks  17  49  0.258  5th of 5
# 71          71  1950-51  NBA   Tri-Cities Blackhawks  25  43  0.368  5th of 5
# 72          72  1949-50  NBA  Tri-Cities Blackhawks*  29  35  0.453  3rd of 6
#
# ...

# %%
prev_season.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73 entries, 0 to 72
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   73 non-null     int64
#  1   Season       73 non-null     object
#  2   Lg           73 non-null     object
#  3   Team         73 non-null     object
#  4   W            73 non-null     int64
#  5   L            73 non-null     int64
#  6   W/L%         73 non-null     float64
#  7   Finish       73 non-null     object
#  8   SRS          73 non-null     float64
#  9   Unnamed: 8   0 non-null      float64
#  10  Pace         72 non-null     float64
#  11  Rel Pace     72 non-null     float64
#  12  ORtg         72 non-null     float64
#  13  Rel ORtg     72 non-null     float64
#  14  DRtg         72 non-null     float64
#  15  Rel DRtg     72 non-null     float64
#  16  Unnamed: 15  0 non-null      float64
#  17  Playoffs     48 non-null     object
# ...

# %%
s20_21 = prev_season[prev_season.Season=='2020-21']
s20_21
# Out:
#    Unnamed: 0   Season   Lg            Team   W   L   W/L%    Finish   SRS  \
# 1           1  2020-21  NBA  Atlanta Hawks*  41  31  0.569  1st of 5  2.14
#
#    Unnamed: 8  Pace  Rel Pace   ORtg  Rel ORtg   DRtg  Rel DRtg  Unnamed: 15  \
# 1         NaN  97.6      -1.6  115.7       3.4  113.3       1.0          NaN
#
#                Playoffs                                 Coaches  \
# 1  Lost E. Conf. Finals  L. Pierce (14-20), N. McMillan (27-11)
#
#             Top WS
# 1  C. Capela (8.2)

# %%
s20_21.columns
# Out:
# Index(['Unnamed: 0', 'Season', 'Lg', 'Team', 'W', 'L', 'W/L%', 'Finish', 'SRS',
#        'Unnamed: 8', 'Pace', 'Rel Pace', 'ORtg', 'Rel ORtg', 'DRtg',
#        'Rel DRtg', 'Unnamed: 15', 'Playoffs', 'Coaches', 'Top WS'],
#       dtype='object')

# %%
s20_21[['Team','W/L%', 'Finish', 'SRS', 'Pace', 'Rel Pace', 'ORtg', 'Rel ORtg', 'DRtg','Rel DRtg','Playoffs', 'Top WS']]
# Out:
#              Team   W/L%    Finish   SRS  Pace  Rel Pace   ORtg  Rel ORtg  \
# 1  Atlanta Hawks*  0.569  1st of 5  2.14  97.6      -1.6  115.7       3.4
#
#     DRtg  Rel DRtg              Playoffs           Top WS
# 1  113.3       1.0  Lost E. Conf. Finals  C. Capela (8.2)

# %%
s20_21["Team"] = s20_21["Team"].str.replace("^[A-Za-z]", "", regex=True)
# Out:
# <ipython-input-187-4c23394ab8f8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s20_21["Team"] = s20_21["Team"].str.replace("^[A-Za-z]", "", regex=True)
