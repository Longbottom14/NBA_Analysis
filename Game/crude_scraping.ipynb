# %%
import requests

# %%
import os

# %%
standings_url_games="https://www.basketball-reference.com/teams/ATL/2022_games.html"

# %%
standings_url_gamelog = "https://www.basketball-reference.com/teams/ATL/2022/gamelog/"
standings_url_advanced = "https://www.basketball-reference.com/teams/ATL/2022/gamelog-advanced/"

# %%
standings_url_starting_lineup = "https://www.basketball-reference.com/teams/ATL/2022_start.html"

# %%
#standings_url_lineups="https://www.basketball-reference.com/teams/ATL/2022/lineups/#lineups_5-man_"
url_lineups="https://www.basketball-reference.com/teams/ATL/2022/lineups/"

# %%
prev_season_url = "https://www.basketball-reference.com/teams/ATL/"

# %%
H2H_url ="https://www.basketball-reference.com/teams/ATL/head2head.html"

# %%
coaches_url = "https://www.basketball-reference.com/teams/ATL/coaches.html"

# %%
referees_url = "https://www.basketball-reference.com/teams/ATL/2022_referees.html"

# %%
data_games = requests.get(standings_url_games)

# %%
data_gamelog = requests.get(standings_url_gamelog)
data_advanced = requests.get(standings_url_advanced)

# %%
data_starting_lineup = requests.get(standings_url_starting_lineup)

# %%
data_starting_lineup
# Out:
# <Response [200]>

# %%
data_lineups = requests.get(url_lineups)

# %%
data_lineups
# Out:
# <Response [200]>

# %%
prev_season_data = requests.get(prev_season_url)

# %%
H2H_data = requests.get(H2H_url)

# %%
coaches_data = requests.get(coaches_url)

# %%
referees_data = requests.get(referees_url)

# %%
from bs4 import BeautifulSoup

# %%
soup_games = BeautifulSoup(data_games.text)

# %%
soup_gamelog = BeautifulSoup(data_gamelog.text)
soup_advanced = BeautifulSoup(data_advanced.text)

# %%
soup_starting_lineup = BeautifulSoup(data_starting_lineup.text)

# %%
soup_lineups = BeautifulSoup(data_lineups.text)#.content,"html.parser")

# %%
soup_lineups
# Out:
# <!DOCTYPE html>
# <html class="no-js" data-root="/home/bbr/deploy/www" data-version="klecko-" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0" name="viewport"/>
# <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/202205101" rel="dns-prefetch"/>
# <!-- Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->
# <script async="true" type="text/javascript">
#     (function() {
# 	var host = window.location.hostname;
# 	var element = document.createElement('script');
# 	var firstScript = document.getElementsByTagName('script')[0];
# 	var url = 'https://quantcast.mgr.consensu.org'
# 	    .concat('/choice/', 'XwNYEpNeFfhfr', '/', host, '/choice.js')
# 	var uspTries = 0;
# 	var uspTriesLimit = 3;
# 	element.async = true;
# 	element.type = 'text/javascript';
# 	element.src = url;
#
# 	firstScript.parentNode.insertBefore(element, firstScript);
#
# ...

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
matches_games = pd.read_html(data_games.text, match="Regular Season")[0]

# %%
matches_gamelog_stats = pd.read_html(data_gamelog.text, match="Regular Season")[0]
matches_advance_stats = pd.read_html(data_advanced.text, match="Regular Season")[0]

# %%
matches_starting_lineup = pd.read_html(data_starting_lineup.text, match="Starting Lineups")[0]

# %%
team_lineups = pd.read_html(data_lineups.text, match="Season")[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-169-802aea308c0c> in <module>
# ----> 1 team_lineups = pd.read_html(data_lineups.text, match="Season")[0]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1111     io = stringify_path(io)
#    1112
# -> 1113     return _parse(
#    1114         flavor=flavor,
#    1115         io=io,
#
# ...

# %%
prev_season = pd.read_html(prev_season_data.text, match="73 Seasons")[0]

# %%
prev_season1 = pd.read_html(prev_season_data.text, match="Seasons")[0]

# %%
prev_season
# Out:
#      Season   Lg                    Team   W   L   W/L%    Finish   SRS  \
# 0   2021-22  NBA          Atlanta Hawks*  43  39  0.524  2nd of 5  1.55
# 1   2020-21  NBA          Atlanta Hawks*  41  31  0.569  1st of 5  2.14
# 2   2019-20  NBA           Atlanta Hawks  20  47  0.299  5th of 5 -7.71
# 3   2018-19  NBA           Atlanta Hawks  29  53  0.354  5th of 5 -6.06
# 4   2017-18  NBA           Atlanta Hawks  24  58  0.293  5th of 5 -5.30
# ..      ...  ...                     ...  ..  ..    ...       ...   ...
# 68  1953-54  NBA         Milwaukee Hawks  21  51  0.292  4th of 4 -4.55
# 69  1952-53  NBA         Milwaukee Hawks  27  44  0.380  5th of 5 -2.49
# 70  1951-52  NBA         Milwaukee Hawks  17  49  0.258  5th of 5 -7.04
# 71  1950-51  NBA   Tri-Cities Blackhawks  25  43  0.368  5th of 5 -3.22
# 72  1949-50  NBA  Tri-Cities Blackhawks*  29  35  0.453  3rd of 6 -1.43
#
#     Unnamed: 8   Pace  Rel Pace   ORtg  Rel ORtg   DRtg  Rel DRtg  \
# ...

# %%
prev_season1
# Out:
#      Season   Lg                    Team   W   L   W/L%    Finish   SRS  \
# 0   2021-22  NBA          Atlanta Hawks*  43  39  0.524  2nd of 5  1.55
# 1   2020-21  NBA          Atlanta Hawks*  41  31  0.569  1st of 5  2.14
# 2   2019-20  NBA           Atlanta Hawks  20  47  0.299  5th of 5 -7.71
# 3   2018-19  NBA           Atlanta Hawks  29  53  0.354  5th of 5 -6.06
# 4   2017-18  NBA           Atlanta Hawks  24  58  0.293  5th of 5 -5.30
# ..      ...  ...                     ...  ..  ..    ...       ...   ...
# 68  1953-54  NBA         Milwaukee Hawks  21  51  0.292  4th of 4 -4.55
# 69  1952-53  NBA         Milwaukee Hawks  27  44  0.380  5th of 5 -2.49
# 70  1951-52  NBA         Milwaukee Hawks  17  49  0.258  5th of 5 -7.04
# 71  1950-51  NBA   Tri-Cities Blackhawks  25  43  0.368  5th of 5 -3.22
# 72  1949-50  NBA  Tri-Cities Blackhawks*  29  35  0.453  3rd of 6 -1.43
#
#     Unnamed: 8   Pace  Rel Pace   ORtg  Rel ORtg   DRtg  Rel DRtg  \
# ...

# %%
H2H = pd.read_html(H2H_data.text, match="38 Opponents")[0]

# %%
H2H1 = pd.read_html(H2H_data.text, match="Opponents")[0]

# %%
coaches = pd.read_html(coaches_data.text, match="30 Coaches")[0]

# %%
coaches = pd.read_html(coaches_data.text, match="Coaches")[0]

# %%
referees = pd.read_html(referees_data.text, match="68 Referees")[0]

# %%
referees = pd.read_html(referees_data.text, match="Referees")[0]

# %%
matches_games
# Out:
#      G               Date  Start (ET)  Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0    1  Thu, Oct 21, 2021       7:30p         NaN  Box Score        NaN
# 1    2  Sat, Oct 23, 2021       6:00p         NaN  Box Score          @
# 2    3  Mon, Oct 25, 2021       7:30p         NaN  Box Score        NaN
# 3    4  Wed, Oct 27, 2021       7:30p         NaN  Box Score          @
# 4    5  Thu, Oct 28, 2021       7:00p         NaN  Box Score          @
# ..  ..                ...         ...         ...        ...        ...
# 83   G               Date  Start (ET)         NaN        NaN        NaN
# 84  81   Fri, Apr 8, 2022       8:00p         NaN  Box Score          @
# 85  82  Sun, Apr 10, 2022       3:30p         NaN  Box Score          @
# 86  83  Wed, Apr 13, 2022       7:00p         NaN  Box Score        NaN
# 87  84  Fri, Apr 15, 2022       7:30p         NaN  Box Score          @
#
#                 Opponent Unnamed: 7 Unnamed: 8   Tm  Opp   W   L  Streak  \
# ...

# %%
matches_advance_stats
# Out:
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                    Rk                  G               Date
# 0                   1                  1         2021-10-21
# 1                   2                  2         2021-10-23
# 2                   3                  3         2021-10-25
# 3                   4                  4         2021-10-27
# 4                   5                  5         2021-10-28
# ..                ...                ...                ...
# 85                 80                 80         2022-04-06
# 86                NaN                NaN                NaN
# 87                 Rk                  G               Date
# 88                 81                 81         2022-04-08
# 89                 82                 82         2022-04-10
#
#    Unnamed: 3_level_0 Unnamed: 4_level_0 Unnamed: 5_level_0  \
#    Unnamed: 3_level_1                Opp                W/L
# 0                 NaN                DAL                  W
# ...

# %%
matches_gamelog_stats
# Out:
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                    Rk                  G               Date
# 0                   1                  1         2021-10-21
# 1                   2                  2         2021-10-23
# 2                   3                  3         2021-10-25
# 3                   4                  4         2021-10-27
# 4                   5                  5         2021-10-28
# ..                ...                ...                ...
# 85                 80                 80         2022-04-06
# 86                NaN                NaN                NaN
# 87                 Rk                  G               Date
# 88                 81                 81         2022-04-08
# 89                 82                 82         2022-04-10
#
#    Unnamed: 3_level_0 Unnamed: 4_level_0 Unnamed: 5_level_0  \
#    Unnamed: 3_level_1                Opp                W/L
# 0                 NaN                DAL                  W
# ...

# %%
matches_starting_lineup
# Out:
#      G        Date  Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0    1  2021-10-21         NaN         NaN  Box Score        NaN
# 1    2  2021-10-23         NaN         NaN  Box Score          @
# 2    3  2021-10-25         NaN         NaN  Box Score        NaN
# 3    4  2021-10-27         NaN         NaN  Box Score          @
# 4    5  2021-10-28         NaN         NaN  Box Score          @
# ..  ..         ...         ...         ...        ...        ...
# 77  78  2022-04-02         NaN         NaN  Box Score        NaN
# 78  79  2022-04-05         NaN         NaN  Box Score          @
# 79  80  2022-04-06         NaN         NaN  Box Score        NaN
# 80  81  2022-04-08         NaN         NaN  Box Score          @
# 81  82  2022-04-10         NaN         NaN  Box Score          @
#
#                 Opponent Unnamed: 7 Unnamed: 8   Tm  Opp   W   L  \
# 0       Dallas Mavericks          W        NaN  113   87   1   0
# ...

# %%
matches_starting_lineup['Starting Lineup'].head()
# Out:
# 0    B. Bogdanović · C. Capela · J. Collins · D. Hu...
# 1    B. Bogdanović · C. Capela · J. Collins · D. Hu...
# 2    B. Bogdanović · C. Capela · J. Collins · K. Hu...
# 3    B. Bogdanović · C. Capela · J. Collins · D. Hu...
# 4    B. Bogdanović · C. Capela · J. Collins · D. Hu...
# Name: Starting Lineup, dtype: object

# %%
matches_starting_lineup['Starting Lineup'][0]
# Out:
# 'B. Bogdanović\xa0· C. Capela\xa0· J. Collins\xa0· D. Hunter\xa0· T. Young'

# %%
matches.columns = matches.columns.droplevel()

# %%
matches
# Out:
#      Rk    G        Date Unnamed: 3_level_1  Opp  W/L   Tm  Opp      ORtg  \
# 0     1    1  2021-10-21                NaN  DAL    W  113   87     109.9
# 1     2    2  2021-10-23                  @  CLE    L   95  101      99.3
# 2     3    3  2021-10-25                NaN  DET    W  122  104     123.1
# 3     4    4  2021-10-27                  @  NOP    W  102   99     110.2
# 4     5    5  2021-10-28                  @  WAS    L  111  122     111.9
# ..  ...  ...         ...                ...  ...  ...  ...  ...       ...
# 85   80   80  2022-04-06                NaN  WAS    W  118  103     121.4
# 86  NaN  NaN         NaN                NaN  NaN  NaN  NaN  NaN  Advanced
# 87   Rk    G        Date                NaN  Opp  W/L   Tm  Opp      ORtg
# 88   81   81  2022-04-08                  @  MIA    L  109  113     114.4
# 89   82   82  2022-04-10                  @  HOU    W  130  114     137.4
#
#         DRtg      Pace       FTr      3PAr       TS%      TRB%      AST%  \
# ...

# %%
prev_season
# Out:
#      Season   Lg                    Team   W   L   W/L%    Finish   SRS  \
# 0   2021-22  NBA          Atlanta Hawks*  43  39  0.524  2nd of 5  1.55
# 1   2020-21  NBA          Atlanta Hawks*  41  31  0.569  1st of 5  2.14
# 2   2019-20  NBA           Atlanta Hawks  20  47  0.299  5th of 5 -7.71
# 3   2018-19  NBA           Atlanta Hawks  29  53  0.354  5th of 5 -6.06
# 4   2017-18  NBA           Atlanta Hawks  24  58  0.293  5th of 5 -5.30
# ..      ...  ...                     ...  ..  ..    ...       ...   ...
# 68  1953-54  NBA         Milwaukee Hawks  21  51  0.292  4th of 4 -4.55
# 69  1952-53  NBA         Milwaukee Hawks  27  44  0.380  5th of 5 -2.49
# 70  1951-52  NBA         Milwaukee Hawks  17  49  0.258  5th of 5 -7.04
# 71  1950-51  NBA   Tri-Cities Blackhawks  25  43  0.368  5th of 5 -3.22
# 72  1949-50  NBA  Tri-Cities Blackhawks*  29  35  0.453  3rd of 6 -1.43
#
#     Unnamed: 8   Pace  Rel Pace   ORtg  Rel ORtg   DRtg  Rel DRtg  \
# ...

# %%
H2H
# Out:
#     Rk               Franchise    G    W    L   W/L%     PS     PA   PS/G  \
# 0    1        Anderson Packers    9    2    7  0.222    739    808   82.1
# 1    2       Baltimore Bullets   28   16   12  0.571   2173   2181   77.6
# 2    3          Boston Celtics  386  147  239  0.381  39586  40936  102.6
# 3    4           Brooklyn Nets  188  103   85  0.548  19607  19056  104.3
# 4    5       Charlotte Hornets  126   67   59  0.532  12888  12741  102.3
# 5    6           Chicago Bulls  252  117  135  0.464  25556  25714  101.4
# 6    7           Chicago Stags    2    1    1  0.500    141    151   70.5
# 7    8     Cleveland Cavaliers  236  127  109  0.538  24192  24058  102.5
# 8    9        Dallas Mavericks   82   45   37  0.549   8398   8278  102.4
# 9   10          Denver Nuggets    7    7    0  1.000    685    566   97.9
# 10  11          Denver Nuggets   95   51   44  0.537  10111  10116  106.4
# 11  12         Detroit Pistons  438  213  225  0.486  44340  44530  101.2
# ...

# %%
coaches
# Out:
#    Unnamed: 0_level_0  Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                    Rk               Coach               From
# 0                   1        Red Auerbach               1950
# 1                   2         Hubie Brown               1977
# 2                   3    Mike Budenholzer               2014
# 3                   4          Larry Drew               2011
# 4                   5  Cotton Fitzsimmons               1973
# 5                   6       Mike Fratello               1981
# 6                   7      Harry Gallatin               1963
# 7                   8       Richie Guerin               1965
# 8                   9         Alex Hannum               1957
# 9                  10         Red Holzman               1954
# 10                 11          Lon Kruger               2001
# 11                 12       Andrew Levane               1953
# 12                 13          John Logan               1951
# ...

# %%
referees
# Out:
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Summary        \
#                    Rk            Referee Unnamed: 2_level_1       G  W  L
# 0                   1   James Capers Jr.                NaN       3  2  1
# 1                   2      Dedric Taylor                NaN       3  2  1
# 2                   3    Scott Twardoski                NaN       2  1  1
# 3                   4       Curtis Blair                NaN       6  2  4
# 4                   5         Nate Green                NaN       2  1  1
# ..                ...                ...                ...     ... .. ..
# 63                 64       Scott Foster                NaN       2  1  1
# 64                 65       Bill Kennedy                NaN       2  2  0
# 65                 66   Jason Goldenberg                NaN       2  2  0
# 66                 67     Tom Washington                NaN       3  2  1
# 67                 68       Nick Buchert                NaN       2  2  0
#
# ...

# %%
standings_url_teams = "https://www.basketball-reference.com/teams/"

# %%
data_teams = requests.get(standings_url_teams)

# %%
soup = BeautifulSoup(page.content, "html.parser") # pass page.content cos its better than page.text
results = soup.find(id="ResultsContainer")

# %%
soup_teams = BeautifulSoup(data_teams.content, "html.parser")
teams_table = soup_teams.find("table",id="teams_active")#[0]
links_teams = teams_table.find_all('a')
links_teams = [l.get("href") for l in links_teams]
links_teams = [l for l in links_teams if '/teams/' in l]

# %%
links_teams
# Out:
# ['/teams/ATL/',
#  '/teams/BOS/',
#  '/teams/NJN/',
#  '/teams/CHA/',
#  '/teams/CHI/',
#  '/teams/CLE/',
#  '/teams/DAL/',
#  '/teams/DEN/',
#  '/teams/DET/',
#  '/teams/GSW/',
#  '/teams/HOU/',
#  '/teams/IND/',
#  '/teams/LAC/',
#  '/teams/LAL/',
#  '/teams/MEM/',
#  '/teams/MIA/',
#  '/teams/MIL/',
#  '/teams/MIN/',
#  '/teams/NOH/',
#  '/teams/NYK/',
#  '/teams/OKC/',
#  '/teams/ORL/',
#  '/teams/PHI/',
#  '/teams/PHO/',
#  '/teams/POR/',
#  '/teams/SAC/',
#  '/teams/SAS/',
#  '/teams/TOR/',
#  '/teams/UTA/',
#  '/teams/WAS/']

# %%
len(links_teams)
# Out:
# 30

# %%
data-template,data-template

# %%
general = soup_games.find("div",{"data-template":"Partials/Teams/Summary"})

# %%
general
# Out:
# <div data-template="Partials/Teams/Summary">
# <h1>
# <span>2021-22</span>
# <span>Atlanta Hawks</span>
# <span class="header_end">Schedule and Results</span>
# </h1>
# <div class="prevnext">
# <a href="/teams/ATL/2021_games.html"><div class="button2 prev">Previous Season</div></a>
# </div>
# <p>
# <strong>Record:</strong>
#
#       43-39, 9th in <a href="/leagues/NBA_2022.html">NBA</a>
#      Eastern Conference
#
#
# </p>
# <p>
# <strong>Last Game:</strong>
# <a href="/boxscores/202204260MIA.html">
#       L 94-97
#          at
#           MIA
#       </a>
# </p>
# <p><strong>Coach:</strong> <a href="/coaches/mcmilna01c.html">Nate McMillan</a> (43-39)</p>
# <p><strong>Executive:</strong> <a href="/executives/schletr01x.html">Travis Schlenk</a></p>
# <p>
# <strong>PTS/G:</strong>
#       113.9 (6th of 30)
#       <strong>Opp PTS/G:</strong>
#       112.4 (21st of 30)
#     </p>
# <p>
# <strong><a href="/about/glossary.html#srs">SRS</a></strong>: 1.55 (14th of 30)
#
# ...

# %%
p_element  = general.find_all('p')

# %%
p_element
# Out:
# [<p>
#  <strong>Record:</strong>
#
#        43-39, 9th in <a href="/leagues/NBA_2022.html">NBA</a>
#       Eastern Conference
#
#
#  </p>,
#  <p>
#  <strong>Last Game:</strong>
#  <a href="/boxscores/202204260MIA.html">
#        L 94-97
#           at
#            MIA
#        </a>
#  </p>,
#  <p><strong>Coach:</strong> <a href="/coaches/mcmilna01c.html">Nate McMillan</a> (43-39)</p>,
#  <p><strong>Executive:</strong> <a href="/executives/schletr01x.html">Travis Schlenk</a></p>,
#  <p>
#  <strong>PTS/G:</strong>
#        113.9 (6th of 30)
#        <strong>Opp PTS/G:</strong>
#        112.4 (21st of 30)
#      </p>,
#  <p>
#  <strong><a href="/about/glossary.html#srs">SRS</a></strong>: 1.55 (14th of 30)
#
#        <strong><a href="/about/glossary.html#pace">Pace</a></strong>: 97.7 (20th of 30)
#      </p>,
#  <p>
#  <strong><a href="/about/glossary.html#off_rtg">Off Rtg</a></strong>: 116.5 (2nd of 30)
# ...

# %%
for element in p_element:
   # print(element.find("strong").text)
    print(element.get_text().strip().split(':'))#.replace('\n',""))
    print("+++++")
    #print(element.get_text().find("Record:"))
    #print(element.get_text().find("Last Game:"))
    arr = element.get_text().strip().split(':')
    arr2=arr[1].strip('')
    print(arr[1].strip(''))
    print("+++++")
    print(arr2.replace('\n','').replace(" ",""))
    print("-----")
# Out:
# ['Record', '\n    \n      43-39, 9th in NBA \n     Eastern Conference']
# +++++
#
#
#       43-39, 9th in NBA
#      Eastern Conference
# +++++
# 43-39,9thinNBAEasternConference
# -----
# ['Last Game', '\n\n      L 94-97 \n         at  \n          MIA']
# +++++
#
#
#       L 94-97
#          at
#           MIA
# +++++
# L94-97atMIA
# -----
# ['Coach', ' Nate McMillan (43-39)']
# +++++
#  Nate McMillan (43-39)
# +++++
# NateMcMillan(43-39)
# -----
# ['Executive', ' Travis Schlenk']
# +++++
#  Travis Schlenk
# +++++
# TravisSchlenk
# -----
# ['PTS/G', ' \n      113.9 (6th of 30)\n      Opp PTS/G', ' \n      112.4 (21st of 30)']
# +++++
#
#       113.9 (6th of 30)
#       Opp PTS/G
# +++++
# 113.9(6thof30)OppPTS/G
# -----
# ['SRS', ' 1.55 (14th of 30)\n      \n      Pace', ' 97.7 (20th of 30)']
# +++++
#  1.55 (14th of 30)
#
#       Pace
# +++++
# 1.55(14thof30)Pace
# -----
# ['Off Rtg', ' 116.5 (2nd of 30)\n      Def Rtg', ' 114.9 (26th of 30)\n      Net Rtg', ' +1.6 (14th of 30)']
# ...

# %%
standings_url_games="https://www.basketball-reference.com/teams/ATL/2022_games.html"

# %%
year="2022"

# %%
standings_url_games_list = ["https://www.basketball-reference.com"+link+year+"_games.html" for link in links_teams]

# %%
standings_url_games_list
# Out:
# ['https://www.basketball-reference.com/teams/ATL/2022_games.html',
#  'https://www.basketball-reference.com/teams/BOS/2022_games.html',
#  'https://www.basketball-reference.com/teams/NJN/2022_games.html',
#  'https://www.basketball-reference.com/teams/CHA/2022_games.html',
#  'https://www.basketball-reference.com/teams/CHI/2022_games.html',
#  'https://www.basketball-reference.com/teams/CLE/2022_games.html',
#  'https://www.basketball-reference.com/teams/DAL/2022_games.html',
#  'https://www.basketball-reference.com/teams/DEN/2022_games.html',
#  'https://www.basketball-reference.com/teams/DET/2022_games.html',
#  'https://www.basketball-reference.com/teams/GSW/2022_games.html',
#  'https://www.basketball-reference.com/teams/HOU/2022_games.html',
#  'https://www.basketball-reference.com/teams/IND/2022_games.html',
#  'https://www.basketball-reference.com/teams/LAC/2022_games.html',
#  'https://www.basketball-reference.com/teams/LAL/2022_games.html',
# ...

# %%
parent_dir="C:/Users/user/Solo Dolo/NBA_Analysis/Game"
directory ="ATL"
path = os.path.join(parent_dir,directory)
os.mkdir(path)

# %%
#matches_games = pd.read_html(data_games.text, match="Regular Season")[0]
path2 = os.path.join(path,'matches.csv')
matches_games.to_csv(path2)

# %%
soup_lineups = BeautifulSoup(data_lineups.text)#.content,"html.parser")

# %%
table_big = soup_lineups.findall('tr')#"table",id="lineups_5-man_")#class_="sortable stats_table now_sortable is_sorted")#
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-160-14ed21868f62> in <module>
# ----> 1 table_big = soup_lineups.findall('tr')#"table",id="lineups_5-man_")#class_="sortable stats_table now_sortable is_sorted")#
#
# TypeError: 'NoneType' object is not callable

# %%
type(soup_lineups)
# Out:
# bs4.BeautifulSoup

# %%
import pandas as pd

# %%
from bs4 import BeautifulSoup

# %%
lineups_url ="https://www.basketball-reference.com/teams/ATL/2022/lineups/"

# %%
data_lineups = requests.get(lineups_url)

# %%
#table = pd.read_html(data_lineups.content, match="5-Man")[0]

# %%
soup_ups = BeautifulSoup(data_lineups.content)

# %%
soup_us
# Out:
# <!DOCTYPE html>
# <html class="no-js" data-root="/home/bbr/deploy/www" data-version="klecko-" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0" name="viewport"/>
# <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/202205101" rel="dns-prefetch"/>
# <!-- Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->
# <script async="true" type="text/javascript">
#     (function() {
# 	var host = window.location.hostname;
# 	var element = document.createElement('script');
# 	var firstScript = document.getElementsByTagName('script')[0];
# 	var url = 'https://quantcast.mgr.consensu.org'
# 	    .concat('/choice/', 'XwNYEpNeFfhfr', '/', host, '/choice.js')
# 	var uspTries = 0;
# 	var uspTriesLimit = 3;
# 	element.async = true;
# 	element.type = 'text/javascript';
# 	element.src = url;
#
# 	firstScript.parentNode.insertBefore(element, firstScript);
#
# ...

# %%
soup = BeautifulSoup(data_lineups.text,'lxml')

# %%
result = soup.find_all('table')#("table", id ='lineups_5-man_')

# %%
result
# Out:
# []
